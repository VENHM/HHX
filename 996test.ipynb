# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pymongo import MongoClient
from pandas.io.json import json_normalize

plt.style.use('ggplot')
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']  #解决seaborn中文字体显示问题
plt.rc('figure', figsize=(10, 10))  #把plt默认的图片size调大一点
plt.rcParams["figure.dpi"] =mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
# %matplotlib inline

# %%
user_data = pd.read_csv("D:/ICU996/996_data/users_data.csv",encoding="utf-8")

# %%
issues_data= pd.read_csv("D:/ICU996/996_data/issues_data.csv")

# %%
user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39987 entries, 0 to 39986
# Data columns (total 32 columns):
# _id                    39987 non-null object
# avatar_url             39987 non-null object
# bio                    10174 non-null object
# blog                   6517 non-null object
# company                5470 non-null object
# created_at             39987 non-null object
# email                  12729 non-null object
# events_url             39987 non-null object
# followers              39987 non-null int64
# followers_url          39987 non-null object
# following              39987 non-null int64
# following_url          39987 non-null object
# gists_url              39987 non-null object
# gravatar_id            0 non-null float64
# hireable               2998 non-null object
# html_url               39987 non-null object
# id                     39987 non-null int64
# location               11286 non-null object
# login                  39987 non-null object
# name                   21224 non-null object
# node_id                39987 non-null object
# organizations_url      39987 non-null object
# public_gists           39987 non-null int64
# public_repos           39987 non-null int64
# received_events_url    39987 non-null object
# repos_url              39987 non-null object
# site_admin             39987 non-null bool
# starred_url            39987 non-null object
# subscriptions_url      39987 non-null object
# type                   39987 non-null object
# updated_at             39987 non-null object
# url                    39987 non-null object
# dtypes: bool(1), float64(1), int64(5), object(25)
# memory usage: 9.5+ MB

# %%
user_data.sample(5)
# Out:
#                             _id  \
# 36699  5c9d1ccf6b678c3a6460366c
# 38778  5c9d1d506b678c3a646046cc
# 37098  5c9d1ce66b678c3a6460398e
# 428    5c9d089b6b678c3a645f1677
# 5372   5c9d0c756b678c3a645f3de1
#
#                                               avatar_url  \
# 36699  https://avatars3.githubusercontent.com/u/12680...
# 38778  https://avatars3.githubusercontent.com/u/39072...
# 37098  https://avatars1.githubusercontent.com/u/76246...
# 428    https://avatars3.githubusercontent.com/u/36947...
# 5372   https://avatars1.githubusercontent.com/u/16065...
#
#                               bio                       blog  \
# 36699  Carnegie Mellon University  http://haoransh.github.io
# 38778                         NaN                        NaN
# 37098                     shipeng                        NaN
# 428                           NaN                        NaN
# 5372   Android Developer、Pythoner                        NaN
#
#                                              company            created_at  \
# 36699  Carnegie Mellon University, Peking University  2015-05-31T08:22:28Z
# 38778                                            NaN  2018-05-08T01:21:11Z
# 37098                                            NaN  2014-05-19T02:12:38Z
# 428                                              NaN  2018-03-01T06:48:41Z
# 5372                                             NaN  2015-11-29T05:53:12Z
#
#                         email  \
# 36699   haoranshi97@gmail.com
# 38778                     NaN
# 37098  Peng.Shi@microsoft.com
# 428                       NaN
# 5372         493038128@qq.com
#
#                                               events_url  followers  \
# 36699  https://api.github.com/users/haoransh/events{/...         34
# 38778  https://api.github.com/users/xiong-xin-xin/eve...          1
# 37098  https://api.github.com/users/zmssp/events{/pri...          1
# 428    https://api.github.com/users/18113996630/event...          0
# 5372   https://api.github.com/users/13733236221/event...          0
#
#                                            followers_url  ...  public_gists  \
# 36699    https://api.github.com/users/haoransh/followers  ...             0
# 38778  https://api.github.com/users/xiong-xin-xin/fol...  ...             0
# 37098       https://api.github.com/users/zmssp/followers  ...             0
# 428    https://api.github.com/users/18113996630/follo...  ...             0
# 5372   https://api.github.com/users/13733236221/follo...  ...             0
#
#       public_repos                                received_events_url  \
# 36699           15  https://api.github.com/users/haoransh/received...
# 38778            1  https://api.github.com/users/xiong-xin-xin/rec...
# 37098            3  https://api.github.com/users/zmssp/received_ev...
# 428              8  https://api.github.com/users/18113996630/recei...
# 5372             2  https://api.github.com/users/13733236221/recei...
#
#                                               repos_url site_admin  \
# 36699       https://api.github.com/users/haoransh/repos      False
# 38778  https://api.github.com/users/xiong-xin-xin/repos      False
# 37098          https://api.github.com/users/zmssp/repos      False
# 428      https://api.github.com/users/18113996630/repos      False
# 5372     https://api.github.com/users/13733236221/repos      False
#
#                                              starred_url  \
# 36699  https://api.github.com/users/haoransh/starred{...
# 38778  https://api.github.com/users/xiong-xin-xin/sta...
# 37098  https://api.github.com/users/zmssp/starred{/ow...
# 428    https://api.github.com/users/18113996630/starr...
# 5372   https://api.github.com/users/13733236221/starr...
#
#                                        subscriptions_url  type  \
# 36699  https://api.github.com/users/haoransh/subscrip...  User
# 38778  https://api.github.com/users/xiong-xin-xin/sub...  User
# 37098   https://api.github.com/users/zmssp/subscriptions  User
# 428    https://api.github.com/users/18113996630/subsc...  User
# 5372   https://api.github.com/users/13733236221/subsc...  User
#
#                  updated_at                                         url
# 36699  2019-03-21T04:51:19Z       https://api.github.com/users/haoransh
# 38778  2019-03-28T02:57:39Z  https://api.github.com/users/xiong-xin-xin
# 37098  2019-03-25T04:14:15Z          https://api.github.com/users/zmssp
# 428    2018-12-28T06:29:35Z    https://api.github.com/users/18113996630
# 5372   2019-03-28T02:34:55Z    https://api.github.com/users/13733236221
#
# [5 rows x 32 columns]

# %%
user_data.iloc[666]
# Out:
# _id                                             5c9d08ab6b678c3a645f1857
# avatar_url             https://avatars2.githubusercontent.com/u/14572...
# bio                                                          智者务其实 愚者争虚名
# blog                                                           dwbbb.com
# company                                                            Qunar
# created_at                                          2015-09-21T13:56:07Z
# email                                                                NaN
# events_url             https://api.github.com/users/dwb1994/events{/p...
# followers                                                             36
# followers_url             https://api.github.com/users/dwb1994/followers
# following                                                             22
# following_url          https://api.github.com/users/dwb1994/following...
# gists_url              https://api.github.com/users/dwb1994/gists{/gi...
# gravatar_id                                                          NaN
# hireable                                                             NaN
# html_url                                      https://github.com/dwb1994
# id                                                              14572889
# location                                                         Beijing
# login                                                            dwb1994
# name                                                                 董文博
# node_id                                             MDQ6VXNlcjE0NTcyODg5
# organizations_url              https://api.github.com/users/dwb1994/orgs
# public_gists                                                           0
# public_repos                                                          16
# received_events_url    https://api.github.com/users/dwb1994/received_...
# repos_url                     https://api.github.com/users/dwb1994/repos
# site_admin                                                         False
# starred_url            https://api.github.com/users/dwb1994/starred{/...
# subscriptions_url      https://api.github.com/users/dwb1994/subscript...
# type                                                                User
# updated_at                                          2019-01-14T03:44:00Z
# url                                 https://api.github.com/users/dwb1994
# Name: 666, dtype: object

# %%
user_data.columns
# Out:
# Index(['_id', 'avatar_url', 'bio', 'blog', 'company', 'created_at', 'email',
#        'events_url', 'followers', 'followers_url', 'following',
#        'following_url', 'gists_url', 'gravatar_id', 'hireable', 'html_url',
#        'id', 'location', 'login', 'name', 'node_id', 'organizations_url',
#        'public_gists', 'public_repos', 'received_events_url', 'repos_url',
#        'site_admin', 'starred_url', 'subscriptions_url', 'type', 'updated_at',
#        'url'],
#       dtype='object')

# %%
# 先去除对于分析无用的字段
user_data.drop(columns = ['_id', 'avatar_url', 'events_url', 'followers_url', 'following_url',
                         'gists_url', 'gravatar_id', 'html_url', 'node_id', 'public_gists', 
                          'received_events_url', 'repos_url', 'site_admin', 'starred_url', 
                         'subscriptions_url', 'type'], 
              inplace = True)

# %%
user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39987 entries, 0 to 39986
# Data columns (total 16 columns):
# bio                  10174 non-null object
# blog                 6517 non-null object
# company              5470 non-null object
# created_at           39987 non-null object
# email                12729 non-null object
# followers            39987 non-null int64
# following            39987 non-null int64
# hireable             2998 non-null object
# id                   39987 non-null int64
# location             11286 non-null object
# login                39987 non-null object
# name                 21224 non-null object
# organizations_url    39987 non-null object
# public_repos         39987 non-null int64
# updated_at           39987 non-null object
# url                  39987 non-null object
# dtypes: int64(4), object(12)
# memory usage: 4.9+ MB

# %%
# 时间类型转换
user_data['created_at'] = pd.to_datetime(user_data['created_at'])
user_data['updated_at'] = pd.to_datetime(user_data['updated_at'])

# %%
issues_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10037 entries, 0 to 10036
# Data columns (total 45 columns):
# _id                         10037 non-null object
# assignee                    0 non-null float64
# assignees                   10037 non-null object
# author_association          10037 non-null object
# body                        4547 non-null object
# closed_at                   0 non-null float64
# comments                    10037 non-null int64
# comments_url                10037 non-null object
# created_at                  10037 non-null object
# events_url                  10037 non-null object
# html_url                    10037 non-null object
# id                          10037 non-null int64
# labels                      10037 non-null object
# labels_url                  10037 non-null object
# locked                      10037 non-null bool
# milestone                   0 non-null float64
# node_id                     10037 non-null object
# number                      10037 non-null int64
# pull_request.diff_url       48 non-null object
# pull_request.html_url       48 non-null object
# pull_request.patch_url      48 non-null object
# pull_request.url            48 non-null object
# repository_url              10037 non-null object
# state                       10037 non-null object
# title                       10037 non-null object
# updated_at                  10037 non-null object
# url                         10037 non-null object
# user.avatar_url             10037 non-null object
# user.events_url             10037 non-null object
# user.followers_url          10037 non-null object
# user.following_url          10037 non-null object
# user.gists_url              10037 non-null object
# user.gravatar_id            0 non-null float64
# user.html_url               10037 non-null object
# user.id                     10037 non-null int64
# user.login                  10037 non-null object
# user.node_id                10037 non-null object
# user.organizations_url      10037 non-null object
# user.received_events_url    10037 non-null object
# user.repos_url              10037 non-null object
# user.site_admin             10037 non-null bool
# user.starred_url            10037 non-null object
# user.subscriptions_url      10037 non-null object
# user.type                   10037 non-null object
# user.url                    10037 non-null object
# dtypes: bool(2), float64(4), int64(4), object(35)
# memory usage: 3.3+ MB

# %%
issues_data.sample(5)
# Out:
#                            _id  assignee assignees author_association  \
# 6664  5c9cf064ff314fc01c0c1837       NaN        []               NONE
# 1891  5c9ce636ff314fc01c0be7d3       NaN        []               NONE
# 175   5c9ce61fff314fc01c0bda5d       NaN        []               NONE
# 7540  5c9cf4d1ff314fc01c0c276a       NaN        []               NONE
# 3926  5c9cebd8ff314fc01c0bfa55       NaN        []               NONE
#
#                                                    body  closed_at  comments  \
# 6664                                                NaN        NaN         0
# 1891      现有996的公司最大的错误就是认为加班一定能提高员工的产出，But, who knows?        NaN         1
# 175                                                 NaN        NaN         1
# 7540                                                NaN        NaN         3
# 3926  下午3时，全国各地群众齐集github，举行隆重的程序员独立大典。我们站在GITHUB向全世...        NaN         0
#
#                                            comments_url            created_at  \
# 6664  https://api.github.com/repos/996icu/996.ICU/is...  2019-03-28T02:43:46Z
# 1891  https://api.github.com/repos/996icu/996.ICU/is...  2019-03-28T00:45:01Z
# 175   https://api.github.com/repos/996icu/996.ICU/is...  2019-03-28T13:25:24Z
# 7540  https://api.github.com/repos/996icu/996.ICU/is...  2019-03-28T03:50:24Z
# 3926  https://api.github.com/repos/996icu/996.ICU/is...  2019-03-27T07:23:32Z
#
#                                              events_url  ...    user.login  \
# 6664  https://api.github.com/repos/996icu/996.ICU/is...  ...      mengyuya
# 1891  https://api.github.com/repos/996icu/996.ICU/is...  ...  chengtengfei
# 175   https://api.github.com/repos/996icu/996.ICU/is...  ...       helldzl
# 7540  https://api.github.com/repos/996icu/996.ICU/is...  ...    CsurnameSP
# 3926  https://api.github.com/repos/996icu/996.ICU/is...  ...    generalbao
#
#               user.node_id                          user.organizations_url  \
# 6664  MDQ6VXNlcjQ2MDE4ODMy      https://api.github.com/users/mengyuya/orgs
# 1891  MDQ6VXNlcjEyNTM5MDI4  https://api.github.com/users/chengtengfei/orgs
# 175   MDQ6VXNlcjMwMjE2MDc=       https://api.github.com/users/helldzl/orgs
# 7540  MDQ6VXNlcjM5OTg0MjI5    https://api.github.com/users/CsurnameSP/orgs
# 3926  MDQ6VXNlcjE4MTg1ODU2    https://api.github.com/users/generalbao/orgs
#
#                                user.received_events_url  \
# 6664  https://api.github.com/users/mengyuya/received...
# 1891  https://api.github.com/users/chengtengfei/rece...
# 175   https://api.github.com/users/helldzl/received_...
# 7540  https://api.github.com/users/CsurnameSP/receiv...
# 3926  https://api.github.com/users/generalbao/receiv...
#
#                                        user.repos_url  user.site_admin  \
# 6664      https://api.github.com/users/mengyuya/repos            False
# 1891  https://api.github.com/users/chengtengfei/repos            False
# 175        https://api.github.com/users/helldzl/repos            False
# 7540    https://api.github.com/users/CsurnameSP/repos            False
# 3926    https://api.github.com/users/generalbao/repos            False
#
#                                        user.starred_url  \
# 6664  https://api.github.com/users/mengyuya/starred{...
# 1891  https://api.github.com/users/chengtengfei/star...
# 175   https://api.github.com/users/helldzl/starred{/...
# 7540  https://api.github.com/users/CsurnameSP/starre...
# 3926  https://api.github.com/users/generalbao/starre...
#
#                                  user.subscriptions_url user.type  \
# 6664  https://api.github.com/users/mengyuya/subscrip...      User
# 1891  https://api.github.com/users/chengtengfei/subs...      User
# 175   https://api.github.com/users/helldzl/subscript...      User
# 7540  https://api.github.com/users/CsurnameSP/subscr...      User
# 3926  https://api.github.com/users/generalbao/subscr...      User
#
#                                        user.url
# 6664      https://api.github.com/users/mengyuya
# 1891  https://api.github.com/users/chengtengfei
# 175        https://api.github.com/users/helldzl
# 7540    https://api.github.com/users/CsurnameSP
# 3926    https://api.github.com/users/generalbao
#
# [5 rows x 45 columns]

# %%
issues_data.iloc[888]
# Out:
# _id                                                  5c9ce625ff314fc01c0bdfef
# assignee                                                                  NaN
# assignees                                                                  []
# author_association                                                       NONE
# body                                                                      NaN
# closed_at                                                                 NaN
# comments                                                                    0
# comments_url                https://api.github.com/repos/996icu/996.ICU/is...
# created_at                                               2019-03-28T02:01:06Z
# events_url                  https://api.github.com/repos/996icu/996.ICU/is...
# html_url                        https://github.com/996icu/996.ICU/issues/2509
# id                                                                  426259315
# labels                                                                     []
# labels_url                  https://api.github.com/repos/996icu/996.ICU/is...
# locked                                                                  False
# milestone                                                                 NaN
# node_id                                              MDU6SXNzdWU0MjYyNTkzMTU=
# number                                                                   2509
# pull_request.diff_url                                                     NaN
# pull_request.html_url                                                     NaN
# pull_request.patch_url                                                    NaN
# pull_request.url                                                          NaN
# repository_url                    https://api.github.com/repos/996icu/996.ICU
# state                                                                    open
# title                                                          参与一下大项目，还有些小激动
# updated_at                                               2019-03-28T02:01:06Z
# url                         https://api.github.com/repos/996icu/996.ICU/is...
# user.avatar_url             https://avatars1.githubusercontent.com/u/17696...
# user.events_url             https://api.github.com/users/AttackingProgramm...
# user.followers_url          https://api.github.com/users/AttackingProgramm...
# user.following_url          https://api.github.com/users/AttackingProgramm...
# user.gists_url              https://api.github.com/users/AttackingProgramm...
# user.gravatar_id                                                          NaN
# user.html_url                          https://github.com/AttackingProgrammer
# user.id                                                              17696037
# user.login                                                AttackingProgrammer
# user.node_id                                             MDQ6VXNlcjE3Njk2MDM3
# user.organizations_url      https://api.github.com/users/AttackingProgramm...
# user.received_events_url    https://api.github.com/users/AttackingProgramm...
# user.repos_url              https://api.github.com/users/AttackingProgramm...
# user.site_admin                                                         False
# user.starred_url            https://api.github.com/users/AttackingProgramm...
# user.subscriptions_url      https://api.github.com/users/AttackingProgramm...
# user.type                                                                User
# user.url                     https://api.github.com/users/AttackingProgrammer
# Name: 888, dtype: object

# %%
# 由于字段太多，,直接抽取想要的字段
issues_data = issues_data[['comments', 'id', 'title', 'updated_at', 'user.id']]

# %%
issues_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10037 entries, 0 to 10036
# Data columns (total 5 columns):
# comments      10037 non-null int64
# id            10037 non-null int64
# title         10037 non-null object
# updated_at    10037 non-null object
# user.id       10037 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 392.1+ KB

# %%
# 时间类型转换
issues_data['updated_at'] = pd.to_datetime(issues_data['updated_at'])
